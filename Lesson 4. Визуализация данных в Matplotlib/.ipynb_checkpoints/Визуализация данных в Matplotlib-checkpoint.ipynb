# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# #### Задание 1
# Создайте список под названием x с числами 1, 2, 3, 4, 5, 6, 7 и список y с числами 3.5, 3.8, 4.2, 4.5, 5, 5.5, 7.
# С помощью функции plot постройте график, соединяющий линиями точки с горизонтальными координатами из списка x и вертикальными - из списка y.
# Затем в следующей ячейке постройте диаграмму рассеяния (другие названия - диаграмма разброса, scatter plot).

# %%
x = [1, 2, 3, 4, 5, 6, 7]
y = [3.5, 3.8, 4.2, 4.5, 5, 5.5, 7]

# %%
title_params = {'fontweight': 'bold', 'fontsize': 16}
axis_x_params = {'fontweight': 'bold', 'fontsize': 12}
axis_y_params = {'fontweight': 'bold', 'fontsize': 12}

# %%
plt.plot(x, y)
plt.title('Linear graph', fontdict = title_params)
plt.xlabel('axis X', fontdict = axis_x_params, loc = 'right')
plt.ylabel('axis Y', fontdict = axis_y_params, loc = 'top')
plt.axis([0, 8, 2, 8])
plt.show()

# %%
plt.scatter(x, y)
plt.title('Scatter graph', fontdict = title_params)
plt.xlabel('axis X', fontdict = axis_x_params, loc = 'right')
plt.ylabel('axis Y', fontdict = axis_y_params, loc = 'top')
plt.axis([0, 8, 2, 8])
plt.show()

# %% [markdown]
# #### Задание 2
# С помощью функции linspace из библиотеки Numpy создайте массив t из 51 числа от 0 до 10 включительно.
# Создайте массив Numpy под названием f, содержащий косинусы элементов массива t.
# Постройте линейную диаграмму, используя массив t для координат по горизонтали,а массив f - для координат по вертикали. Линия графика должна быть зеленого цвета.
# Выведите название диаграммы - 'График f(t)'. Также добавьте названия для горизонтальной оси - 'Значения t' и для вертикальной - 'Значения f'.
# Ограничьте график по оси x значениями 0.5 и 9.5, а по оси y - значениями -2.5 и 2.5.

# %%
t = np.linspace(0, 10, 51)
f = np.cos(t)

# %%
plt.plot(t, f, color = 'g')
plt.title('График f(t)', fontdict = title_params)
plt.xlabel('Значения t', fontdict = axis_x_params, loc = 'right')
plt.ylabel('Значения f', fontdict = axis_y_params, loc = 'top')
plt.axis([0.5, 9.5, -2.5, 2.5])
plt.grid(color = 'ghostwhite')
plt.show()

# %% [markdown]
# #### Задание 3
# С помощью функции linspace библиотеки Numpy создайте массив x из 51 числа от -3 до 3 включительно.
# Создайте массивы y1, y2, y3, y4 по следующим формулам:
# y1 = x**2
# y2 = 2 * x + 0.5
# y3 = -3 * x - 1.5
# y4 = sin(x)
# Используя функцию subplots модуля matplotlib.pyplot, создайте объект matplotlib.figure.Figure с названием fig и массив объектов Axes под названием ax,причем так, чтобы у вас было 4 отдельных графика в сетке, состоящей из двух строк и двух столбцов.
#
# В каждом графике массив x используется для координат по горизонтали.В левом верхнем графике для координат по вертикали используйте y1,в правом верхнем - y2, в левом нижнем - y3, в правом нижнем - y4.Дайте название графикам: 'График y1', 'График y2' и т.д.
# Для графика в левом верхнем углу установите границы по оси x от -5 до 5.
# Установите размеры фигуры 8 дюймов по горизонтали и 6 дюймов по вертикали.
# Вертикальные и горизонтальные зазоры между графиками должны составлять 0.3.

# %%
x = np.linspace(-3, 3, 51)
y1 = x ** 2
y2 = 2 * x + 0.5
y3 = -3 * x - 1.5
y4 = np.sin(x)

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 2)
ax1, ax2, ax3, ax4 = ax.flatten()
fig.set_size_inches(8, 6)
fig.subplots_adjust(wspace=0.3, hspace=0.3)

ax1.plot(x, y1)
ax1.set_xlim([-5, 5])
ax1.set_title('График y1', loc = 'Left')
ax1.grid(color = 'ghostwhite')

ax2.plot(x, y2)
ax2.set_title('График y2', loc = 'Left')
ax2.grid(color = 'ghostwhite')

ax3.plot(x, y3)
ax3.set_title('График y3', loc = 'Left')
ax3.grid(color = 'ghostwhite')

ax4.plot(x, y4)
ax4.set_title('График y4', loc = 'Left')
ax4.grid(color = 'ghostwhite')

# %% [markdown]
# #### Задание 4
# Ознакомьтесь с описанием и скачайте датасет creditcard.csv.
# Данный датасет является примером несбалансированных данных, так как мошеннические операции с картами встречаются реже обычных.
# Импортруйте библиотеку Pandas, а также используйте для графиков стиль “fivethirtyeight”.
# Посчитайте с помощью метода value_counts количество наблюдений для каждого значения целевой переменной Class и примените к полученным данным метод plot, чтобы построить столбчатую диаграмму. Затем постройте такую же диаграмму, используя логарифмический масштаб.
# На следующем графике постройте две гистограммы по значениям признака V1 - одну для мошеннических транзакций (Class равен 1) и другую - для обычных (Class равен 0). Подберите значение аргумента  density так, чтобы по вертикали графика было расположено не число наблюдений, а плотность распределения. Число бинов должно равняться 20 для обеих гистограмм, а коэффициент alpha сделайте равным 0.5, чтобы гистограммы были полупрозрачными и не загораживали друг друга. Создайте легенду с двумя значениями: “Class 0” и “Class 1”. Гистограмма обычных транзакций должна быть серого цвета, а мошеннических - красного. Горизонтальной оси дайте название “Class”.

# %%
plt.style.use('fivethirtyeight')

# %%
data = pd.read_csv('creditcard.csv')
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
a = pd.DataFrame(data.value_counts('Class'))
a.columns = ['Count']
a
# Out:
#         Count
# Class
# 0      284315
# 1         492

# %%
a.plot()
plt.title('График f(t)', fontdict = title_params)
plt.xlabel('Значения t', fontdict = axis_x_params, loc = 'right')
plt.ylabel('Значения f', fontdict = axis_y_params, loc = 'top')
plt.grid(color = 'ghostwhite')

# %%
a.plot(kind="bar", logy=True)
# Out:
# <AxesSubplot:xlabel='Class'>

# %% [markdown]
# ####
# На следующем графике постройте две гистограммы по значениям признака V1 - одну для мошеннических транзакций (Class равен 1) и другую - для обычных (Class равен 0).
# (не совместил на одном графике - не смог)

# %%
dataV1_0 = pd.DataFrame(data, columns = ['V1', 'Class'])
dataV1_0 = dataV1_0.loc[dataV1_0.Class == 0]
dataV1_0
dataV1_0.hist(column='V1', bins=20, alpha = 0.5, density=True, color='grey')
plt.title('График V1 для обычных транзакций', fontdict = title_params)
plt.xlabel('axis Class', fontdict = axis_x_params, loc = 'right')
plt.legend(labels=["Class 0"])
plt.axis([-7, 3, 0, 0.8])

dataV1_1 = pd.DataFrame(data, columns = ['V1', 'Class'])
dataV1_1 = dataV1_1.loc[dataV1_1.Class == 1]
dataV1_1
dataV1_1.hist(column='V1', bins=20, density=True, color='red')
plt.title('График V1 для мошенических транзакций', fontdict = title_params)
plt.xlabel('axis Class', fontdict = axis_x_params, loc = 'right')
plt.legend(labels=["Class 1"])
plt.axis([-10, 0, 0, 0.5])
# Out:
# (-10.0, 0.0, 0.0, 0.5)
